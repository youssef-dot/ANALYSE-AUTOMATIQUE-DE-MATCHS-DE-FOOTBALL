# %%
pip install ultralytics

# %%
# !pip install ultralytics
from ultralytics import YOLO

model= YOLO('/content/drive/MyDrive/Colab Notebooks/projet_cv/models/best.pt')

# Modifying the predict call to explicitly define the project and name for saving
results=model.predict('/content/drive/MyDrive/Colab Notebooks/projet_cv/input_videos/08fd33_4.mp4', save=True, project='/content/drive/MyDrive/Colab Notebooks/projet_cv/output_videos', name='yolov8_output')

print(results[0])

print('==============================')

for box in results[0].boxes :
  print(box)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 77.3 MB/s eta 0:00:00
# ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
#
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

directory_to_list = '/content/drive/MyDrive/Colab Notebooks/projet_cv/output_videos'

if os.path.exists(directory_to_list):
    print(f"Contents of {directory_to_list}:")
    for item in os.listdir(directory_to_list):
        print(item)
else:
    print(f"Directory {directory_to_list} does not exist. Please ensure the YOLO model has completed its prediction and created the directory.")
# Out:
# Contents of /content/drive/MyDrive/Colab Notebooks/projet_cv/output_videos:
# yolov8_output
# yolov8_output-2
